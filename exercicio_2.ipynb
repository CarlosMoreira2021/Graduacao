# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosMoreira2021/Graduacao/blob/main/exercicio_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Bem vindo a Lanchonete do Carlos Eduardo Moreira de Oliveira')
print('----RU: 3615321')

print("**************Cardapio*************")

print('|Codigo |      Descricao        | Valor |')

print('|  100  |   Cachorro Quente     | 9,00  |')

print('|  101  | Cachorro Quente Duplo | 11,00 |')

print('|  102  |         Ex-Egg        | 12,00 |')

print('|  103  |         X-Salada      | 12,00 |')

print('|  104  |         X-Bacon       | 14,00 |')

print('|  105  |         X-Tudo        | 17,00 |')

print('|  200  |   Refrigerante Lata   | 5,00  |')

print('|  201  |       Chá Gelado      | 4,00  |')

while True:
    # codigo para digitacao

    # -----------produtos
    cq = 9.00
    cqd = 11.00
    xe = 12.00
    xs = 12.00
    xb = 14.00
    xt = 17.00
    refri = 5.00
    cha = 4.00
    # --------------------------
    cod = str(input('Entre com o codigo desejado: '))

    if cod != '100' and cod != "101" and cod != "102" and cod != "103" and cod != "104" and cod != "105" and cod != "200" and cod != "201":
        print('Opcao invalida')
        continue

    elif cod == "100":                  
        print('Voce pediu um Cachorro quente no valor de {}'.format(cq))
        print('Deseja mais alguma coisa? ')
        print('1- Sim ')
        print('2- Não ')
        saida = str(input())
        if saida == '2':
            break
        elif saida != '1':
            continue

    elif cod == "101":       
        print('Voce pediu um Cachorro quente Duplo no valor de {}'.format(cqd))
        print('Deseja mais alguma coisa? ')
        print('1- Sim ')
        print('2- Não ')
        saida = str(input())
        if saida == '2':
            break
        elif saida != '1':
            continue

    elif cod == "102":
        print('Voce pediu um X-Egg no valor de {}'.format(xe))
        print('Deseja mais alguma coisa? ')
        print('1- Sim ')
        print('2- Não ')
        saida = str(input())
        if saida == '2':
            break
        elif saida != '1':
            continue

    elif cod == "103":
        print('Voce pediu um X-Salada no valor de {}'.format(xs))
        print('Deseja mais alguma coisa? ')
        print('1- Sim ')
        print('2- Não ')
        saida = str(input())
        if saida == '2':
            break
        elif saida != '1':
            continue

    elif cod == "104":
        print('Voce pediu um X-Bacon no valor de {}'.format(xb))
        print('Deseja mais alguma coisa? ')
        print('1- Sim ')
        print('2- Não ')
        saida = str(input())
        if saida == '2':
            break
        elif saida != '1':
            continue

    elif cod == "105":
        print('Voce pediu um X-Tudo no valor de {}'.format(xt))
        print('Deseja mais alguma coisa? ')
        print('1- Sim ')
        print('2- Não ')
        saida = str(input())
        if saida == '2':
            break
        elif saida != '1':
            continue

    elif cod == "200":
        print('Voce pediu um Refrigerante Lata no valor de {}'.format(refri))
        print('Deseja mais alguma coisa? ')
        print('1- Sim ')
        print('2- Não ')
        saida = str(input())
        if saida == '2':
            break
        elif saida != '1':
            continue

    elif cod == "201":
        print('Voce pediu um Chá gelado no valor de {}'.format(cha))
        print('Deseja mais alguma coisa? ')
        print('1- Sim ')
        print('2- Não ')
        saida = str(input())
        if saida == '2':
            break
        elif saida != '1':
            continue
