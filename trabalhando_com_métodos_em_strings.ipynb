# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosMoreira2021/Graduacao/blob/main/trabalhando_com_m%C3%A9todos_em_strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#verifica se existe a palavra no inicio ou nao a palavra na string e retorna verdadeiro ou falso
s1 = 'Logica de programacao e algoritmos'
s1.startswith("Logica")
# Out:
# False

# %%
s1 = 'Logica de programacao'
print(s1.lower())
print(s1.upper())
# Out:
# logica de programacao
# LOGICA DE PROGRAMACAO

# %%
#substituir palavra

s1 = 'Um mafagafinho , dois mafagafinhos, tres mafagafinhos...'
s1.replace('mafagafinho','gatinho')
# Out:
# 'Um gatinho , dois gatinhos, tres gatinhos...'

# %% [markdown]
# ![image.png](data:image/png;base64,...)
